# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Dense, Dropout,
    BatchNormalization, Activation,
    GlobalAveragePooling2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.metrics import Precision, Recall
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Import custom logger
sys.path.append('..')
from result_logger import log_result


# =========================================================
print("GPU Available:", len(tf.config.list_physical_devices('GPU')) > 0)

# SYSTEM CHECK
print("TensorFlow Version:", tf.__version__)
# =========================================================
# Out:
# 2026-02-02 06:09:51.236716: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-02 06:09:52.594611: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-02 06:10:24.444601: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# GPU Available: True
# TensorFlow Version: 2.20.0

# %%
# =========================================================
# CONFIGURATION
# =========================================================
IMG_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 50

PUBLIC_DIR = "../Dataset/preprocessed_Public"
SELF_DIR = "../Dataset/SelfCollected_Dataset"

CLASS_NAMES = sorted(os.listdir(PUBLIC_DIR))
NUM_CLASSES = len(CLASS_NAMES)

# Create models directory
os.makedirs('models', exist_ok=True)


print("Classes:", CLASS_NAMES)
# Out:
# Classes: ['test', 'train', 'val']

# %%
# =========================================================
# CLASS NAMES
# =========================================================
CLASS_NAMES = sorted([
    d for d in os.listdir(os.path.join(PUBLIC_DIR, "train"))
    if os.path.isdir(os.path.join(PUBLIC_DIR, "train", d))
])

NUM_CLASSES = len(CLASS_NAMES)

print("Classes:", CLASS_NAMES)
# Out:
# Classes: ['aluminium', 'paper', 'plastic']

# %%
# =========================================================
# DATA GENERATORS 
# =========================================================
train_datagen = ImageDataGenerator(
    rescale=1./255   # Only normalization
)

val_datagen = ImageDataGenerator(
    rescale=1./255
)

test_datagen = ImageDataGenerator(
    rescale=1./255
)

# %%
# =========================================================
# LOAD DATA FROM DIRECTORIES
# =========================================================
train_gen = train_datagen.flow_from_directory(
    os.path.join(PUBLIC_DIR, "train"),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=True
)

val_gen = val_datagen.flow_from_directory(
    os.path.join(PUBLIC_DIR, "val"),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

test_gen = test_datagen.flow_from_directory(
    os.path.join(SELF_DIR),
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False
)

print("\n📊 Dataset Summary")
print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)
print("Test samples (self):", test_gen.samples)
# Out:
# Found 7512 images belonging to 3 classes.
# Found 403 images belonging to 3 classes.
# Found 533 images belonging to 3 classes.
#
# 📊 Dataset Summary
# Train samples: 7512
# Validation samples: 403
# Test samples (self): 533

# %%
# =========================================================
# CNN MODEL (MEMORY SAFE)
# =========================================================
model = Sequential([
    Conv2D(32, 3, padding='same', input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),

    Conv2D(64, 3, padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),

    Conv2D(128, 3, padding='same'),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(),

    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(
    optimizer=Adam(1e-4),
    loss="categorical_crossentropy",
    metrics=['accuracy', Precision(name='precision'), Recall(name='recall')]
)

print("\n📋 Model Summary")
model.summary()
# Out:
# /mnt/c/laragon/www/CV-project/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769983849.393872    1266 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5592 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# 📋 Model Summary
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,043 (433.76 KB)
#  Trainable params: 110,595 (432.01 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# =========================================================
# CALLBACKS
# =========================================================
callbacks = [
    EarlyStopping(patience=8, restore_best_weights=True),
    ReduceLROnPlateau(patience=4),
    ModelCheckpoint(
        'models/customvgg_raw.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# %%
# =========================================================
# TRAINING
# =========================================================
print("\n🚀 Training started...\n")

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print("\n✅ Training complete!")
# Out:
# 🚀 Training started...
#
# Epoch 1/50
# 2026-02-02 06:10:52.672903: I external/local_xla/xla/service/service.cc:163] XLA service 0x7886dc003270 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-02-02 06:10:52.672927: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Ti, Compute Capability 8.6
# 2026-02-02 06:10:52.781044: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-02 06:10:53.189432: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91801
#   3/470 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.4479 - loss: 1.1257 - precision: 0.3333 - recall: 0.1111
# I0000 00:00:1769983858.767791    2213 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5607 - loss: 0.9181 - precision: 0.6389 - recall: 0.4001
# Epoch 1: val_accuracy improved from None to 0.53598, saving model to models/customvgg_raw.keras
#
# Epoch 1: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 41s 72ms/step - accuracy: 0.6140 - loss: 0.8394 - precision: 0.6903 - recall: 0.4706 - val_accuracy: 0.5360 - val_loss: 0.8976 - val_precision: 0.6387 - val_recall: 0.3772 - learning_rate: 1.0000e-04
# Epoch 2/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6716 - loss: 0.7440 - precision: 0.7437 - recall: 0.5575
# Epoch 2: val_accuracy improved from 0.53598 to 0.63275, saving model to models/customvgg_raw.keras
#
# Epoch 2: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0.6852 - loss: 0.7283 - precision: 0.7499 - recall: 0.5720 - val_accuracy: 0.6328 - val_loss: 0.8005 - val_precision: 0.6762 - val_recall: 0.5285 - learning_rate: 1.0000e-04
# Epoch 3/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7065 - loss: 0.6841 - precision: 0.7681 - recall: 0.6185
# Epoch 3: val_accuracy did not improve from 0.63275
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 25s 53ms/step - accuracy: 0.7133 - loss: 0.6788 - precision: 0.7714 - recall: 0.6274 - val_accuracy: 0.6253 - val_loss: 0.7763 - val_precision: 0.6817 - val_recall: 0.5633 - learning_rate: 1.0000e-04
# Epoch 4/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7303 - loss: 0.6458 - precision: 0.7906 - recall: 0.6507
# Epoch 4: val_accuracy improved from 0.63275 to 0.69231, saving model to models/customvgg_raw.keras
#
# Epoch 4: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 25s 53ms/step - accuracy: 0.7304 - loss: 0.6420 - precision: 0.7860 - recall: 0.6543 - val_accuracy: 0.6923 - val_loss: 0.6298 - val_precision: 0.7341 - val_recall: 0.6303 - learning_rate: 1.0000e-04
# Epoch 5/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7488 - loss: 0.6124 - precision: 0.7943 - recall: 0.6840
# Epoch 5: val_accuracy improved from 0.69231 to 0.69479, saving model to models/customvgg_raw.keras
#
# Epoch 5: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 23s 50ms/step - accuracy: 0.7493 - loss: 0.6114 - precision: 0.7970 - recall: 0.6832 - val_accuracy: 0.6948 - val_loss: 0.6199 - val_precision: 0.7444 - val_recall: 0.6576 - learning_rate: 1.0000e-04
# Epoch 6/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7525 - loss: 0.5951 - precision: 0.7979 - recall: 0.6908
# Epoch 6: val_accuracy improved from 0.69479 to 0.81886, saving model to models/customvgg_raw.keras
#
# Epoch 6: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.7634 - loss: 0.5797 - precision: 0.8051 - recall: 0.7027 - val_accuracy: 0.8189 - val_loss: 0.4799 - val_precision: 0.8623 - val_recall: 0.7767 - learning_rate: 1.0000e-04
# Epoch 7/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7751 - loss: 0.5621 - precision: 0.8159 - recall: 0.7201
# Epoch 7: val_accuracy did not improve from 0.81886
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 54ms/step - accuracy: 0.7712 - loss: 0.5656 - precision: 0.8125 - recall: 0.7106 - val_accuracy: 0.7519 - val_loss: 0.5572 - val_precision: 0.7842 - val_recall: 0.7122 - learning_rate: 1.0000e-04
# Epoch 8/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7716 - loss: 0.5561 - precision: 0.8128 - recall: 0.7223
# Epoch 8: val_accuracy did not improve from 0.81886
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.7796 - loss: 0.5508 - precision: 0.8203 - recall: 0.7278 - val_accuracy: 0.5856 - val_loss: 1.0377 - val_precision: 0.6105 - val_recall: 0.5757 - learning_rate: 1.0000e-04
# Epoch 9/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7959 - loss: 0.5150 - precision: 0.8346 - recall: 0.7472
# Epoch 9: val_accuracy did not improve from 0.81886
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 25s 54ms/step - accuracy: 0.7889 - loss: 0.5268 - precision: 0.8286 - recall: 0.7387 - val_accuracy: 0.5806 - val_loss: 1.2311 - val_precision: 0.5881 - val_recall: 0.5633 - learning_rate: 1.0000e-04
# Epoch 10/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7931 - loss: 0.5115 - precision: 0.8341 - recall: 0.7401
# Epoch 10: val_accuracy did not improve from 0.81886
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 25s 54ms/step - accuracy: 0.7898 - loss: 0.5227 - precision: 0.8268 - recall: 0.7399 - val_accuracy: 0.7618 - val_loss: 0.5969 - val_precision: 0.7917 - val_recall: 0.7072 - learning_rate: 1.0000e-04
# Epoch 11/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8058 - loss: 0.4979 - precision: 0.8427 - recall: 0.7587
# Epoch 11: val_accuracy improved from 0.81886 to 0.85856, saving model to models/customvgg_raw.keras
#
# Epoch 11: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 27s 57ms/step - accuracy: 0.8067 - loss: 0.4959 - precision: 0.8431 - recall: 0.7576 - val_accuracy: 0.8586 - val_loss: 0.3980 - val_precision: 0.8937 - val_recall: 0.8139 - learning_rate: 1.0000e-05
# Epoch 12/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8019 - loss: 0.4900 - precision: 0.8416 - recall: 0.7613
# Epoch 12: val_accuracy did not improve from 0.85856
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.8102 - loss: 0.4804 - precision: 0.8496 - recall: 0.7686 - val_accuracy: 0.8412 - val_loss: 0.4103 - val_precision: 0.8760 - val_recall: 0.8065 - learning_rate: 1.0000e-05
# Epoch 13/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8079 - loss: 0.4829 - precision: 0.8457 - recall: 0.7664
# Epoch 13: val_accuracy did not improve from 0.85856
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.8135 - loss: 0.4761 - precision: 0.8488 - recall: 0.7700 - val_accuracy: 0.8586 - val_loss: 0.3911 - val_precision: 0.9014 - val_recall: 0.8164 - learning_rate: 1.0000e-05
# Epoch 14/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8208 - loss: 0.4666 - precision: 0.8564 - recall: 0.7744
# Epoch 14: val_accuracy improved from 0.85856 to 0.86352, saving model to models/customvgg_raw.keras
#
# Epoch 14: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 54ms/step - accuracy: 0.8178 - loss: 0.4685 - precision: 0.8533 - recall: 0.7721 - val_accuracy: 0.8635 - val_loss: 0.3931 - val_precision: 0.8889 - val_recall: 0.8139 - learning_rate: 1.0000e-05
# Epoch 15/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8137 - loss: 0.4740 - precision: 0.8444 - recall: 0.7711
# Epoch 15: val_accuracy did not improve from 0.86352
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0.8131 - loss: 0.4766 - precision: 0.8460 - recall: 0.7706 - val_accuracy: 0.8462 - val_loss: 0.3889 - val_precision: 0.8907 - val_recall: 0.8089 - learning_rate: 1.0000e-05
# Epoch 16/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8161 - loss: 0.4692 - precision: 0.8490 - recall: 0.7669
# Epoch 16: val_accuracy did not improve from 0.86352
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 25s 54ms/step - accuracy: 0.8155 - loss: 0.4724 - precision: 0.8458 - recall: 0.7694 - val_accuracy: 0.8586 - val_loss: 0.3926 - val_precision: 0.8904 - val_recall: 0.8065 - learning_rate: 1.0000e-05
# Epoch 17/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8107 - loss: 0.4733 - precision: 0.8464 - recall: 0.7731
# Epoch 17: val_accuracy improved from 0.86352 to 0.86600, saving model to models/customvgg_raw.keras
#
# Epoch 17: finished saving model to models/customvgg_raw.keras
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0.8152 - loss: 0.4695 - precision: 0.8495 - recall: 0.7741 - val_accuracy: 0.8660 - val_loss: 0.3813 - val_precision: 0.8827 - val_recall: 0.8213 - learning_rate: 1.0000e-05
# Epoch 18/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8239 - loss: 0.4680 - precision: 0.8603 - recall: 0.7830
# Epoch 18: val_accuracy did not improve from 0.86600
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0
val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 27s 57ms/step - accuracy: 0.8288 - loss: 0.4549 - precision: 0.8579 - recall: 0.7867 - val_accuracy: 0.8685 - val_loss: 0.3699 - val_precision: 0.9101 - val_recall: 0.8288 - learning_rate: 1.0000e-07
# Epoch 39/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8247 - loss: 0.4525 - precision: 0.8585 - recall: 0.7819
# Epoch 39: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 0.8228 - loss: 0.4594 - precision: 0.8560 - recall: 0.7788 - val_accuracy: 0.8660 - val_loss: 0.3706 - val_precision: 0.9103 - val_recall: 0.8313 - learning_rate: 1.0000e-07
# Epoch 40/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8323 - loss: 0.4471 - precision: 0.8619 - recall: 0.7896
# Epoch 40: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 28s 59ms/step - accuracy: 0.8279 - loss: 0.4528 - precision: 0.8608 - recall: 0.7842 - val_accuracy: 0.8685 - val_loss: 0.3714 - val_precision: 0.9071 - val_recall: 0.8238 - learning_rate: 1.0000e-07
# Epoch 41/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8174 - loss: 0.4602 - precision: 0.8506 - recall: 0.7752
# Epoch 41: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 28s 59ms/step - accuracy: 0.8190 - loss: 0.4580 - precision: 0.8532 - recall: 0.7785 - val_accuracy: 0.8710 - val_loss: 0.3702 - val_precision: 0.9103 - val_recall: 0.8313 - learning_rate: 1.0000e-07
# Epoch 42/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8199 - loss: 0.4601 - precision: 0.8543 - recall: 0.7797
# Epoch 42: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 27s 56ms/step - accuracy: 0.8229 - loss: 0.4548 - precision: 0.8563 - recall: 0.7837 - val_accuracy: 0.8635 - val_loss: 0.3711 - val_precision: 0.9098 - val_recall: 0.8263 - learning_rate: 1.0000e-07
# Epoch 43/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8264 - loss: 0.4522 - precision: 0.8602 - recall: 0.7855
# Epoch 43: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.8271 - loss: 0.4505 - precision: 0.8593 - recall: 0.7859 - val_accuracy: 0.8660 - val_loss: 0.3710 - val_precision: 0.9079 - val_recall: 0.8313 - learning_rate: 1.0000e-08
# Epoch 44/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8270 - loss: 0.4468 - precision: 0.8614 - recall: 0.7845
# Epoch 44: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.8279 - loss: 0.4524 - precision: 0.8609 - recall: 0.7817 - val_accuracy: 0.8660 - val_loss: 0.3714 - val_precision: 0.9074 - val_recall: 0.8263 - learning_rate: 1.0000e-08
# Epoch 45/50
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8216 - loss: 0.4553 - precision: 0.8563 - recall: 0.7826
# Epoch 45: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 54ms/step - accuracy: 0.8251 - loss: 0.4501 - precision: 0.8594 - recall: 0.7853 - val_accuracy: 0.8660 - val_loss: 0.3710 - val_precision: 0.9030 - val_recall: 0.8313 - learning_rate: 1.0000e-08
# Epoch 46/50
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8203 - loss: 0.4547 - precision: 0.8574 - recall: 0.7858
# Epoch 46: val_accuracy did not improve from 0.87097
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.8224 - loss: 0.4549 - precision: 0.8581 - recall: 0.7831 - val_accuracy: 0.8660 - val_loss: 0.3701 - val_precision: 0.9030 - val_recall: 0.8313 - learning_rate: 1.0000e-08
#
# ✅ Training complete!

# %%
# =========================================================
# TRAINING CURVES
# =========================================================
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Val')
plt.title('Accuracy')
plt.legend()
plt.grid()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Val')
plt.title('Loss')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
# ============================
# EVALUATION ON SELF-COLLECTED DATA
# ============================


print("\n📊 Evaluating on SELF-COLLECTED dataset...")


test_loss, test_acc, test_prec, test_rec = model.evaluate(test_gen, verbose=0)
test_f1 = 2 * (test_prec * test_rec) / (test_prec + test_rec)
print(f"Test Accuracy: {test_acc*100:.2f}%")
print(f"Test Precision: {test_prec*100:.2f}%")
print(f"Test Recall: {test_rec*100:.2f}%")
print(f"Test F1-score: {test_f1*100:.2f}%")


# Predictions
y_pred_prob = model.predict(test_gen)
y_pred = np.argmax(y_pred_prob, axis=1)
y_true = test_gen.classes


# Classification report
print("\n📋 Classification Report")
print(classification_report(y_true, y_pred, target_names=test_gen.class_indices.keys()))


# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
xticklabels=test_gen.class_indices.keys(),
yticklabels=test_gen.class_indices.keys())
plt.title('Confusion Matrix – CustomVGG CNN (Raw)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.tight_layout()
plt.show()

# Log results to CSV
log_result(
    model_name='CustomVGG_CNN',
    experiment_type='Raw',
    accuracy=test_acc,
    precision=test_prec,
    recall=test_rec,
    f1=test_f1,
    loss=test_loss
)

print("✅ Evaluation completed and results logged")
# Out:
# 📊 Evaluating on SELF-COLLECTED dataset...
# Test Accuracy: 26.64%
# Test Precision: 26.86%
# Test Recall: 23.08%
# Test F1-score: 24.82%
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step
#
# 📋 Classification Report
#               precision    recall  f1-score   support
#
#    aluminium       0.41      0.22      0.29       148
#        paper       0.23      0.51      0.32       151
#      plastic       0.28      0.14      0.18       234
#
#     accuracy                           0.27       533
#    macro avg       0.30      0.29      0.26       533
# weighted avg       0.30      0.27      0.25       533
# ✓ Results logged: CustomVGG_CNN - Raw
#   Accuracy: 0.2664, Precision: 0.2686, Recall: 0.2308, F1: 0.2482
# ✅ Evaluation completed and results logged

# %% [markdown]
# # =========================================================
# # LOAD SAVED MODEL (OPTIONAL)
# # =========================================================
# If you have already trained the model, load it instead of training again

# %%
# Load saved model if it exists
def load_saved_model(model_path):
    """
    Load a saved Keras model
    
    Args:
        model_path: Path to the saved model file
    
    Returns:
        Loaded Keras model or None
    """
    if os.path.exists(model_path):
        print(f"Loading model from {model_path}")
        from tensorflow import keras
        model = keras.models.load_model(model_path)
        print("✓ Model loaded successfully")
        return model
    else:
        print(f"❌ Model not found at {model_path}")
        return None

# Try to load the saved model
model_path = 'models/customvgg_raw.keras'
loaded_model = load_saved_model(model_path)

if loaded_model is not None:
    print("\n📊 Evaluating loaded model on test set...")
    
    # Recreate test generator
    test_gen = test_datagen.flow_from_directory(
        os.path.join(SELF_DIR),
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=BATCH_SIZE,
        class_mode="categorical",
        shuffle=False
    )
    
    # Evaluate
    test_loss, test_acc, test_prec, test_rec = loaded_model.evaluate(test_gen, verbose=1)
    test_f1 = 2 * (test_prec * test_rec) / (test_prec + test_rec)
    
    print(f"\nLoaded Model Results:")
    print(f"Test Accuracy: {test_acc*100:.2f}%")
    print(f"Test Precision: {test_prec*100:.2f}%")
    print(f"Test Recall: {test_rec*100:.2f}%")
    print(f"Test F1-score: {test_f1*100:.2f}%")
    
    # Log results
    log_result(
        model_name='CustomVGG_CNN',
        experiment_type='Preprocessed_on_Raw',
        accuracy=test_acc,
        precision=test_prec,
        recall=test_rec,
        f1=test_f1,
        loss=test_loss
    )
    
    print("✓ Results logged to final_results.csv")
else:
    print("⚠️ No saved model found. Please train the model first.")
# Out:
# Loading model from models/customvgg_raw.keras
# ✓ Model loaded successfully
#
# 📊 Evaluating loaded model on test set...
# Found 533 images belonging to 3 classes.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.2720 - loss: 1.7704 - precision: 0.2741 - recall: 0.2345
#
# Loaded Model Results:
# Test Accuracy: 27.20%
# Test Precision: 27.41%
# Test Recall: 23.45%
# Test F1-score: 25.28%
# ✓ Results logged: CustomVGG_CNN - Raw
#   Accuracy: 0.2720, Precision: 0.2741, Recall: 0.2345, F1: 0.2528
# ✓ Results logged to final_results.csv
